# %%
import os
import joblib
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Assuming your CSV files are in the same directory as your script or notebook
csv_folder_path = 'C:/Users/EEstaff/Desktop/NPPVData(2021-2023)/filtered_data'

# Get a list of all CSV files in the folder
csv_files = [file for file in os.listdir(csv_folder_path) if file.endswith('.csv')]

# Create a dictionary to store DataFrames
dfs = {}

# Load each CSV file into a DataFrame and store it in the dictionary
for csv_file in csv_files:
    df_name = f"df_{os.path.splitext(csv_file)[0]}"  # Name the DataFrame based on the CSV file name
    df = pd.read_csv(os.path.join(csv_folder_path, csv_file))
    dfs[df_name] = df
    
for df_name, df in dfs.items():
    # Train your model using dfs
    from sklearn.model_selection import train_test_split
    from sklearn.ensemble import GradientBoostingRegressor, RandomForestRegressor
    from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
    from sklearn.ensemble import VotingRegressor
    
    # Reset the index of the DataFrame
    dfs[df_name] = df.reset_index(drop=True)

    # Split the dataset into features and labels
    X = dfs[df_name][['temp', 'humidity', 'pressure', 'IRR Value W/m²']]
    y = dfs[df_name][['Energy kWh']]

    X = X.rename(str, axis="columns")
    y = y.rename(str, axis="columns")

    # Assuming X and y are your features and labels
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

    # Initialize individual models
    gradient_boosting_model = GradientBoostingRegressor()
    random_forest_model = RandomForestRegressor()

    # Build an ensemble model using VotingRegressor
    ensemble_model = VotingRegressor(estimators=[
        ('gradient_boosting', gradient_boosting_model),
        ('random_forest', random_forest_model)
    ])

    # Train the ensemble model
    ensemble_model.fit(X_train, y_train)

    # Make predictions on the test set
    y_pred = ensemble_model.predict(X_test)

    # Evaluate the performance of the ensemble model
    mse = mean_squared_error(y_test, y_pred)
    mae = mean_absolute_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)

    # Assume 'model' is your trained model
    joblib.dump(ensemble_model, f'model_{df_name}.pkl')

    # Print or store results
    print(f"Training completed for {df_name}")
    print(f'Mean Squared Error: {mse:.3f}')
    print(f'Mean Absolute Error: {mae:.3f}')
    print(f'R-squared: {r2:.3f}')
    
    axis_x = [i for i in range(100)]
    plt.figure(figsize=(10, 5))
    plt.plot(axis_x, y_test[:100], label='actual')
    plt.plot(axis_x, y_pred[:100], label='predict')
    plt.title(f'Result for {df_name}')
    plt.legend()
    plt.show()
# Out:
# C:\Users\EEstaff\AppData\Roaming\Python\Python311\site-packages\sklearn\ensemble\_voting.py:607: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Training completed for df_blk37
# Mean Squared Error: 2.931
# Mean Absolute Error: 0.920
# R-squared: 0.934
# C:\Users\EEstaff\AppData\Roaming\Python\Python311\site-packages\sklearn\ensemble\_voting.py:607: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Training completed for df_blk39
# Mean Squared Error: 10.079
# Mean Absolute Error: 1.798
# R-squared: 0.890
# C:\Users\EEstaff\AppData\Roaming\Python\Python311\site-packages\sklearn\ensemble\_voting.py:607: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Training completed for df_blk40
# Mean Squared Error: 7.163
# Mean Absolute Error: 1.523
# R-squared: 0.925
# C:\Users\EEstaff\AppData\Roaming\Python\Python311\site-packages\sklearn\ensemble\_voting.py:607: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Training completed for df_blk47
# Mean Squared Error: 3.130
# Mean Absolute Error: 0.995
# R-squared: 0.929
# C:\Users\EEstaff\AppData\Roaming\Python\Python311\site-packages\sklearn\ensemble\_voting.py:607: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Training completed for df_blk50
# Mean Squared Error: 0.878
# Mean Absolute Error: 0.522
# R-squared: 0.920
# C:\Users\EEstaff\AppData\Roaming\Python\Python311\site-packages\sklearn\ensemble\_voting.py:607: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Training completed for df_blk52
# Mean Squared Error: 0.442
# Mean Absolute Error: 0.354
# R-squared: 0.935
# C:\Users\EEstaff\AppData\Roaming\Python\Python311\site-packages\sklearn\ensemble\_voting.py:607: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Training completed for df_blk56
# Mean Squared Error: 0.158
# Mean Absolute Error: 0.223
# R-squared: 0.923
# C:\Users\EEstaff\AppData\Roaming\Python\Python311\site-packages\sklearn\ensemble\_voting.py:607: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Training completed for df_blk58
# Mean Squared Error: 1.055
# Mean Absolute Error: 0.577
# R-squared: 0.937
# C:\Users\EEstaff\AppData\Roaming\Python\Python311\site-packages\sklearn\ensemble\_voting.py:607: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Training completed for df_blk68
# Mean Squared Error: 5.077
# Mean Absolute Error: 1.261
# R-squared: 0.920
# C:\Users\EEstaff\AppData\Roaming\Python\Python311\site-packages\sklearn\ensemble\_voting.py:607: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Training completed for df_blk72
# Mean Squared Error: 0.955
# Mean Absolute Error: 0.523
# R-squared: 0.932
# C:\Users\EEstaff\AppData\Roaming\Python\Python311\site-packages\sklearn\ensemble\_voting.py:607: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Training completed for df_blk80
# Mean Squared Error: 1.518
# Mean Absolute Error: 0.616
# R-squared: 0.929
# C:\Users\EEstaff\AppData\Roaming\Python\Python311\site-packages\sklearn\ensemble\_voting.py:607: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Training completed for df_blk83
# Mean Squared Error: 0.348
# Mean Absolute Error: 0.302
# R-squared: 0.938

# %%
import os
import joblib
import pandas as pd
import mysql.connector
import sqlalchemy
import datetime

# Assuming your CSV files are in the same directory as your script or notebook
csv_folder_path = 'C:/Users/EEstaff/Desktop/NPPVData(2021-2023)/filtered_data'

# Get a list of all CSV files in the folder
csv_files = [file for file in os.listdir(csv_folder_path) if file.endswith('.csv')]

# Create a dictionary to store DataFrames
dfs = {}

# Load each CSV file into a DataFrame and store it in the dictionary
for csv_file in csv_files:
    df_name = f"df_{os.path.splitext(csv_file)[0]}"  # Name the DataFrame based on the CSV file name
    df = pd.read_csv(os.path.join(csv_folder_path, csv_file))
    dfs[df_name] = df

connection = mysql.connector.connect(
    host='localhost',
    user='root',
    password='password',
    database='mqtt_data'
)
cursor = connection.cursor()
query = "SELECT AVG(light_bh1750) AS light FROM solar_iot_box WHERE timestamp > NOW() - INTERVAL 5 MINUTE" 
cursor.execute(query)
data = cursor.fetchall()
df4 = pd.DataFrame(data, columns=['IRR Value W/m²'])
df4['IRR Value W/m²'] = df4['IRR Value W/m²'] / 52

query = "SELECT AVG(temperature_dht11) AS temp FROM solar_iot_box WHERE timestamp > NOW() - INTERVAL 5 MINUTE"
cursor.execute(query)
data = cursor.fetchall()
df1 = pd.DataFrame(data, columns=['temp'])

query = "SELECT AVG(humidity_dht11) AS humidity FROM solar_iot_box WHERE timestamp > NOW() - INTERVAL 5 MINUTE"
cursor.execute(query)
data = cursor.fetchall()
df2 = pd.DataFrame(data, columns=['humidity'])

query = "SELECT AVG(pressure_bme280) AS pressure FROM solar_iot_box WHERE timestamp > NOW() - INTERVAL 5 MINUTE"
cursor.execute(query)
data = cursor.fetchall()
df3 = pd.DataFrame(data, columns=['pressure'])

combined_df = pd.concat([df1, df2, df3, df4], axis=1)
combined_df.fillna(combined_df.mean(), inplace=True)

print(combined_df)

predictions_df = pd.DataFrame()
for df_name, df in dfs.items():
    model = joblib.load(f'model_{df_name}.pkl')
    prediction = model.predict(combined_df)
    predictions_df[df_name] = prediction / 12

print(predictions_df)

# Get the current timestamp
current_timestamp = datetime.datetime.now()
# Insert a new column at the first index with the current timestamp
predictions_df.insert(0, 'Timestamp', current_timestamp)

# MySQL configurations
db_config = {
    'host': 'localhost',
    'user': 'root',
    'password': 'password',
    'database': 'ftp_data'
}

# Function to execute a query
def execute_query(db_config, query):
    try:
        # Create a database connection
        connection = mysql.connector.connect(
            host=db_config['host'],
            user=db_config['user'],
            passwd=db_config['password'],
            database=db_config['database']
        )
        cursor = connection.cursor()
        # Execute the query
        cursor.execute(query, multi=True)
        # Commit the changes
        connection.commit()
    except mysql.connector.Error as err:
        print(f"Error: {err}")

# Create a connection to the database
engine = sqlalchemy.create_engine(f'mysql+mysqlconnector://root:password@localhost:3306/np_solar_data')

# Insert the DataFrame into MySQL using the to_sql() method
predictions_df.to_sql('solar_predictions', con=engine, if_exists='append', index=False)
